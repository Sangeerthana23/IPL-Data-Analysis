# %% [markdown]
# ## IMPORT LIBRARIES

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
# %matplotlib inline

# %%
a=pd.read_csv("IPL_Players_Data(2008-2022).csv")

# %%
a
# Out:
#       Unnamed: 0               Playerss  Year  Matches  Runss Average  \
# 0              0            Jos Buttler  2022       17    863   57.53
# 1              1              K L Rahul  2022       15    616   51.33
# 2              2        Quinton De Kock  2022       15    508   36.29
# 3              3          Hardik Pandya  2022       15    487   44.27
# 4              4           Shubman Gill  2022       16    483   34.50
# ...          ...                    ...   ...      ...    ...     ...
# 2170        2170  Paidikalva Vijaykumar  2008        9      1    0.00
# 2171        2171           Abdur Razzak  2008        1      0    0.00
# 2172        2172         Abhinav Mukund  2008        2      0    0.00
# 2173        2173    Lakshmipathy Balaji  2008        9      0    0.00
# 2174        2174            Munaf Patel  2008       15      0    0.00
#
#      Higest_score  Strike Rate  NO  Fifty  Four  Six
# 0             116       149.05   2      4    83   45
# ...

# %% [markdown]
# ## DATA PRE-PROCESSING

# %%
a.shape
# Out:
# (2175, 12)

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2175 entries, 0 to 2174
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    2175 non-null   int64
#  1   Playerss      2175 non-null   object
#  2   Year          2175 non-null   int64
#  3   Matches       2175 non-null   int64
#  4   Runss         2175 non-null   int64
#  5   Average       2175 non-null   object
#  6   Higest_score  2175 non-null   object
#  7   Strike Rate   2175 non-null   float64
#  8   NO            2175 non-null   int64
#  9   Fifty         2175 non-null   int64
#  10  Four          2175 non-null   int64
#  11  Six           2175 non-null   int64
# dtypes: float64(1), int64(8), object(3)
# memory usage: 204.0+ KB

# %%
a.head()
# Out:
#    Unnamed: 0         Playerss  Year  Matches  Runss Average Higest_score  \
# 0           0      Jos Buttler  2022       17    863   57.53          116
# 1           1        K L Rahul  2022       15    616   51.33         103*
# 2           2  Quinton De Kock  2022       15    508   36.29         140*
# 3           3    Hardik Pandya  2022       15    487   44.27          87*
# 4           4     Shubman Gill  2022       16    483   34.50           96
#
#    Strike Rate  NO  Fifty  Four  Six
# 0       149.05   2      4    83   45
# 1       135.38   3      4    45   30
# 2       148.97   1      3    47   23
# 3       131.26   4      4    49   12
# 4       132.32   2      4    51   11

# %%
a.tail()
# Out:
#       Unnamed: 0               Playerss  Year  Matches  Runss Average  \
# 2170        2170  Paidikalva Vijaykumar  2008        9      1    0.00
# 2171        2171           Abdur Razzak  2008        1      0    0.00
# 2172        2172         Abhinav Mukund  2008        2      0    0.00
# 2173        2173    Lakshmipathy Balaji  2008        9      0    0.00
# 2174        2174            Munaf Patel  2008       15      0    0.00
#
#      Higest_score  Strike Rate  NO  Fifty  Four  Six
# 2170           1*        100.0   2      0     0    0
# 2171           0*          0.0   1      0     0    0
# 2172           0*          0.0   0      0     0    0
# 2173           0*          0.0   0      0     0    0
# 2174           0*          0.0   2      0     0    0

# %%
a.describe()
# Out:
#         Unnamed: 0         Year      Matches        Runss  Strike Rate  \
# count  2175.000000  2175.000000  2175.000000  2175.000000  2175.000000
# mean   1087.000000  2014.975632     8.971954   127.968736   110.754023
# std     628.012739     4.368476     5.012647   155.303463    45.131397
# min       0.000000  2008.000000     1.000000     0.000000     0.000000
# 25%     543.500000  2011.000000     4.000000    11.000000    88.415000
# 50%    1087.000000  2015.000000     9.000000    53.000000   116.260000
# 75%    1630.500000  2019.000000    14.000000   203.000000   135.700000
# max    2174.000000  2022.000000    19.000000   973.000000   400.000000
#
#                 NO        Fifty         Four          Six
# count  2175.000000  2175.000000  2175.000000  2175.000000
# mean      1.520920     0.648276    11.606897     4.868966
# std       1.596742     1.250562    15.405511     7.040416
# min       0.000000     0.000000     0.000000     0.000000
# ...

# %%
a.isnull().sum()
# Out:
# Unnamed: 0      0
# Playerss        0
# Year            0
# Matches         0
# Runss           0
# Average         0
# Higest_score    0
# Strike Rate     0
# NO              0
# Fifty           0
# Four            0
# Six             0
# dtype: int64

# %%
a.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2170    False
# 2171    False
# 2172    False
# 2173    False
# 2174    False
# Length: 2175, dtype: bool

# %%
a["Year"].unique()
# Out:
# array([2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012,
#        2011, 2010, 2009, 2008], dtype=int64)

# %% [markdown]
# ## DATA CLEANING

# %% [markdown]
# ## RENAMING COLUMNS

# %%
a.rename(columns={"Playerss":"Player",
                 "Runss":"Runs",
                 "Strike Rate":"Strike_rate",
                 "Higest_score":"High_score",
                 "NO":"Not_Out"},inplace=True)
a
# Out:
#       Unnamed: 0                 Player  Year  Matches  Runs Average  \
# 0              0            Jos Buttler  2022       17   863   57.53
# 1              1              K L Rahul  2022       15   616   51.33
# 2              2        Quinton De Kock  2022       15   508   36.29
# 3              3          Hardik Pandya  2022       15   487   44.27
# 4              4           Shubman Gill  2022       16   483   34.50
# ...          ...                    ...   ...      ...   ...     ...
# 2170        2170  Paidikalva Vijaykumar  2008        9     1    0.00
# 2171        2171           Abdur Razzak  2008        1     0    0.00
# 2172        2172         Abhinav Mukund  2008        2     0    0.00
# 2173        2173    Lakshmipathy Balaji  2008        9     0    0.00
# 2174        2174            Munaf Patel  2008       15     0    0.00
#
#      High_score  Strike_rate  Not_Out  Fifty  Four  Six
# 0           116       149.05        2      4    83   45
# ...

# %% [markdown]
# ## REMOVING COLUMNS

# %%
a.drop(columns="Unnamed: 0",inplace=True)

# %%
a
# Out:
#                      Player  Year  Matches  Runs Average High_score  \
# 0               Jos Buttler  2022       17   863   57.53        116
# 1                 K L Rahul  2022       15   616   51.33       103*
# 2           Quinton De Kock  2022       15   508   36.29       140*
# 3             Hardik Pandya  2022       15   487   44.27        87*
# 4              Shubman Gill  2022       16   483   34.50         96
# ...                     ...   ...      ...   ...     ...        ...
# 2170  Paidikalva Vijaykumar  2008        9     1    0.00         1*
# 2171           Abdur Razzak  2008        1     0    0.00         0*
# 2172         Abhinav Mukund  2008        2     0    0.00         0*
# 2173    Lakshmipathy Balaji  2008        9     0    0.00         0*
# 2174            Munaf Patel  2008       15     0    0.00         0*
#
#       Strike_rate  Not_Out  Fifty  Four  Six
# 0          149.05        2      4    83   45
# 1          135.38        3      4    45   30
# ...

# %% [markdown]
# ## MODIFYING DATATYPES

# %%
a['High_score'] = a['High_score'].str.replace('*', '', regex=False).astype(int)
a['Average'] = pd.to_numeric(a['Average'], errors='coerce')

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2175 entries, 0 to 2174
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Player       2175 non-null   object
#  1   Year         2175 non-null   int64
#  2   Matches      2175 non-null   int64
#  3   Runs         2175 non-null   int64
#  4   Average      2167 non-null   float64
#  5   High_score   2175 non-null   int32
#  6   Strike_rate  2175 non-null   float64
#  7   Not_Out      2175 non-null   int64
#  8   Fifty        2175 non-null   int64
#  9   Four         2175 non-null   int64
#  10  Six          2175 non-null   int64
# dtypes: float64(2), int32(1), int64(7), object(1)
# memory usage: 178.5+ KB

# %% [markdown]
# ## OUTLIERS

# %%
plt.boxplot(a["Runs"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x26c4502fb00>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x26c450600e0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x26c4502c080>],
#  'medians': [<matplotlib.lines.Line2D at 0x26c450606b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x26c450609b0>],
#  'means': []}

# %% [markdown]
# ## EXPLORATORY DATA ANALYSIS

# %% [markdown]
# ## TOP RUN SCORERS

# %%
top_scorers=a.groupby("Player")["Runs"].sum().sort_values(ascending=False).head(10)

# %%
print(top_scorers)
# Out:
# Player
# Virat Kohli       6624
# Shikhar Dhawan    6244
# Rohit Sharma      5879
# David Warner      5718
# Suresh Raina      5528
# MS Dhoni          4978
# Chris Gayle       4965
# Robin Uthappa     4952
# AB de Villiers    4697
# Ambati Rayudu     4190
# Name: Runs, dtype: int64

# %% [markdown]
# ## BAR CHART(TOP RUN SCORERS)

# %%
plt.figure(figsize=(7,4))
sns.barplot(x=top_scorers.values,y=top_scorers.index, palette="magma")
plt.title("TOP SCORERS",fontsize=15)
plt.xlabel("Runs",fontsize=15)
plt.ylabel("Player",fontsize=15)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\BHUVIBHUVANA\AppData\Local\Temp\ipykernel_20228\1216000624.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_scorers.values,y=top_scorers.index, palette="magma")

# %% [markdown]
# ## TOTAL NUMBER OF SIXES BY TOP 10 PLAYERS

# %%
sixes=a.groupby(by="Player")["Six"].sum().sort_values(ascending=False).head(10)

# %%
print(sixes)
# Out:
# Player
# Chris Gayle       357
# Rohit Sharma      240
# AB de Villiers    239
# MS Dhoni          229
# Kieron Pollard    223
# Virat Kohli       218
# David Warner      211
# Suresh Raina      203
# Shane Watson      190
# Robin Uthappa     182
# Name: Six, dtype: int64

# %% [markdown]
# ## PIE CHART(TOTAL NUMBER OF SIXES BY TOP 10 PLAYERS)

# %%
plt.figure(figsize=(5,5))
sixes.plot(kind='pie',autopct='%1.1f%%', startangle=90,colors=plt.cm.Paired.colors, textprops={"fontsize":8,}
              ,wedgeprops={"linewidth":0.5,'edgecolor':'black'})
plt.title("TOP 10 SIX HITTERS – % DISTRIBUTION",fontsize=15)
plt.ylabel('Six',fontsize=15)
plt.show()

# %% [markdown]
# ## TOTAL NUMBER OF FOURS BY TOP 10 PLAYERS

# %%
fours=a.groupby(by="Player")["Four"].sum().sort_values(ascending=False).head(10)

# %%
print(fours)
# Out:
# Player
# Shikhar Dhawan    701
# Virat Kohli       578
# David Warner      561
# Rohit Sharma      519
# Suresh Raina      506
# Robin Uthappa     481
# Gautam Gambhir    459
# Ajinkya Rahane    431
# Dinesh Karthik    406
# Chris Gayle       405
# Name: Four, dtype: int64

# %% [markdown]
# ## BARH CHART(TOTAL NUMBER OF FOURS BY TOP 10 PLAYERS)

# %%
plt.figure(figsize=(7,4))
plt.barh(fours.index[::-1], fours.values[::-1],color='grey',edgecolor="black")
plt.title("TOP 10 PLAYERS BY FOURS (2008–2022)",fontsize=15,color="grey")
plt.xlabel("No Of Fours",fontsize=15,color="grey")
plt.ylabel("Players",fontsize=15,color="grey")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## TOTAL NUMBER OF NOTOUT BY TOP 10 PLAYERS

# %%
not_out=a.groupby("Player")["Not_Out"].sum().sort_values(ascending=False).head(10)

# %%
print(not_out)
# Out:
# Player
# MS Dhoni           79
# Ravindra Jadeja    67
# Kieron Pollard     52
# Dwayne Bravo       44
# Yusuf Pathan       44
# Dinesh Karthik     40
# Harbhajan Singh    37
# AB de Villiers     36
# Hardik Pandya      35
# David Miller       35
# Name: Not_Out, dtype: int64

# %% [markdown]
# ## LINE CHART(TOTAL NUMBER OF NOTOUT BY TOP 5 PLAYERS)

# %%
plt.figure(figsize=(7,4))
not_out.plot(kind="line",color='green')
plt.title("TOP 10 PLAYERS BY NOT OUT (2008–2022)",fontsize=15,color="green")
plt.xlabel("Players",fontsize=15,color="green")
plt.ylabel("No Of Notout",fontsize=15,color="green")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## TOP 10 STRIKE RATE OF A BATSMEN (MINIMUM 10 MATCHES PLAYED)

# %%
strikerate=a[a["Matches"]<=10].groupby("Player")["Strike_rate"].mean().sort_values(ascending=False).head(10)

# %%
print(strikerate)
# Out:
# Player
# Raiphi Gomez       400.00
# Prerak Mankad      400.00
# Bhargav Bhatt      300.00
# Abu Nechim         300.00
# Billy Stanlake     250.00
# Deepak Chahar      233.33
# Umar Gul           205.26
# Syed Mohammad      200.64
# Reetinder Sodhi    200.00
# Sam Curran         182.91
# Name: Strike_rate, dtype: float64

# %% [markdown]
# ## BAR PLOT(STRIKE RATE OF A BATSMEN)

# %%
plt.figure(figsize=(7,4))
sns.barplot(strikerate,palette="viridis")
plt.title("TOP 10 PLAYERS BY STRIKE RATE (Min 10 Matches)",fontsize=15)
plt.xlabel("Players",fontsize=15)
plt.ylabel("Average Strike Rate",fontsize=15)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\BHUVIBHUVANA\AppData\Local\Temp\ipykernel_20228\1293756696.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(strikerate,palette="viridis")

# %% [markdown]
# ## MOST NUMBER OF FIFTY BY TOP 10 PLAYERS

# %%
fifties=a.groupby("Player")["Fifty"].sum().sort_values(ascending=False).head(10)

# %%
print(fifties)
# Out:
# Player
# David Warner      54
# Shikhar Dhawan    47
# Virat Kohli       44
# Rohit Sharma      40
# Suresh Raina      39
# AB de Villiers    37
# Gautam Gambhir    35
# Chris Gayle       31
# Ajinkya Rahane    28
# Robin Uthappa     27
# Name: Fifty, dtype: int64

# %% [markdown]
# ## SCATTER PLOT(NUMBER OF FIFTIES BY TOP 10 PLAYERS)

# %%
plt.figure(figsize=(7,4))
sns.scatterplot(x=fifties.values,y=fifties.index,color="purple")
plt.title("NUMBER OF FIFTIES BY TOP 10 PALYERS",fontsize=15,color='purple')
plt.xlabel("Count of Fifties",fontsize=15,color="purple")
plt.ylabel("Players",fontsize=15,color="purple")
ax=plt.gca()
ax.set_facecolor("silver")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## TOP 10 AVERAGE OF A BATSMEN (MINIMUM 20 MATCHES PLAYED)

# %%
average=a[a["Matches"]<20].groupby("Player")["Average"].mean().sort_values(ascending=False).head(10)

# %%
print(average)
# Out:
# Player
# Simon Katich       56.055000
# K L Rahul          51.330000
# Luke Pomersbach    51.000000
# Matthew Hayden     45.540000
# Adam Voges         45.250000
# Andrew Symonds     45.115000
# Hashim Amla        43.080000
# JP Duminy          42.676250
# David Warner       42.666667
# MS Dhoni           42.376000
# Name: Average, dtype: float64

# %% [markdown]
# ## HIST CHART(AVERAGE OF A BATSMEN)

# %%
plt.figure(figsize=(7,4))
sns.histplot(average, bins=20, color='xkcd:rust', edgecolor='black',kde=True)
plt.title("DISTRIBUTON OF TOP 10 PLAYERS BATTING AVERAGE",fontsize=15,color="xkcd:rust")
plt.xlabel("Average",fontsize=15,color="xkcd:rust")
plt.ylabel("Number of Players",fontsize=15,color='xkcd:rust')
ax=plt.gca()
ax.set_facecolor("silver")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## TOTAL NUMBER OF RUNS SCORED PER SEASON

# %%
 runs_year=a.groupby("Year")["Runs"].sum()

# %%
runs_year
# Out:
# Year
# 2008    16699
# 2009    13157
# 2010    17696
# 2011    19903
# 2012    21317
# 2013    21416
# 2014    17918
# 2015    17409
# 2016    17962
# 2017    17907
# 2018    19098
# 2019    18574
# 2020    18508
# 2021    17716
# 2022    23052
# Name: Runs, dtype: int64

# %% [markdown]
# ## LINE CHART(TOTAL RUNS PER SEASON)

# %%
plt.figure(figsize=(7,4))
runs_year.plot(kind="line",color="red")
plt.xlabel("Year",fontsize=15)
plt.ylabel("Total Runs",fontsize=15)
plt.title("TOTAL RUNS PER SEASON (2008-2022)",fontsize=15)
ax=plt.gca()
ax.set_facecolor("silver")
plt.grid(True)
plt.show()

# %% [markdown]
# ## TOTAL NUMBER OF SIXES PER SEASON

# %%
sixes_per_year=a.groupby("Year")["Six"].sum()

# %%
sixes_per_year
# Out:
# Year
# 2008     620
# 2009     456
# 2010     583
# 2011     638
# 2012     731
# 2013     674
# 2014     714
# 2015     692
# 2016     638
# 2017     705
# 2018     872
# 2019     784
# 2020     734
# 2021     687
# 2022    1062
# Name: Six, dtype: int64

# %% [markdown]
# ## PIE CHART(TOTAL NUMBER OF SIXES PER SEASON)

# %%
plt.figure(figsize=(5,5))
sixes_per_year.plot(kind='pie',autopct="%0.1f%%",radius=1.0,labeldistance=1.1,textprops={"fontsize":9},
                    wedgeprops={"linewidth":0.8,'edgecolor':'black'},colors=plt.cm.Paired.colors)
plt.title("NUMBER OF SIXES PER SEASON (2008-2022)",fontsize=15)
plt.ylabel('Six',fontsize=15)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## NUMBER OF FOURS SCORED PER SEASON

# %%
fours_per_year=a.groupby("Year")["Four"].sum()

# %%
fours_per_year
# Out:
# Year
# 2008    1692
# 2009    1110
# 2010    1705
# 2011    1915
# 2012    1911
# 2013    2051
# 2014    1562
# 2015    1607
# 2016    1632
# 2017    1608
# 2018    1652
# 2019    1653
# 2020    1582
# 2021    1548
# 2022    2017
# Name: Four, dtype: int64

# %% [markdown]
# ## DONUT CHART(NUMBER OF FOURS SCORED PER SEASON)

# %%
plt.figure(figsize=(7,4))
fours_per_year.plot(kind='pie',radius=1.4,autopct="%1.0f%%",colors=plt.cm.Paired.colors)
plt.pie([1],colors='w')
plt.show()

# %% [markdown]
# ## NUMBER OF FIFTIES SCORED PER SEASON

# %%
fifty_per_year=a.groupby("Year")["Fifty"].sum()

# %%
print(fifty_per_year)
# Out:
# Year
# 2008     83
# 2009     56
# 2010     88
# 2011     89
# 2012     96
# 2013     97
# 2014     91
# 2015     89
# 2016    110
# 2017     95
# 2018    101
# 2019    106
# 2020    110
# 2021     89
# 2022    110
# Name: Fifty, dtype: int64

# %% [markdown]
# ## BAR PLOT(TOTAL NUMBER OF FIFTIES PER SEASON)

# %%
plt.figure(figsize=(7,4))
sns.barplot(fifty_per_year,palette="rocket")
plt.title(" TOTAL NUMBER OF FIFTIES PER SEASON ",fontsize=15)
plt.xlabel("Year",fontsize=15)
plt.ylabel("No Of Fifty",fontsize=15)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\BHUVIBHUVANA\AppData\Local\Temp\ipykernel_20228\3119187235.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(fifty_per_year,palette="rocket")

# %% [markdown]
# ## AVERAGE RUNS PER SEASON

# %%
avg_per_year=a.groupby('Year')['Average'].sum()

# %%
avg_per_year
# Out:
# Year
# 2008    2879.03
# 2009    2057.60
# 2010    2728.45
# 2011    2929.16
# 2012    2864.67
# 2013    2767.44
# 2014    2406.69
# 2015    2363.35
# 2016    2545.47
# 2017    2532.46
# 2018    2562.66
# 2019    2491.61
# 2020    2575.71
# 2021    2572.60
# 2022    3081.84
# Name: Average, dtype: float64

# %% [markdown]
# ## HIST CHART(AVERAGE RUNS PER SEASON)

# %%
plt.figure(figsize=(7,4))
avg_per_year.hist(bins=20,color='mediumseagreen')
plt.title('AVERAGE RUNS PER SEASON',fontsize=15,color='mediumseagreen')
plt.xlabel('Year',fontsize=15,color='mediumseagreen')
plt.ylabel('Avearge Run',fontsize=15,color='mediumseagreen')
plt.grid(False)
plt.tight_layout()
ax=plt.gca()
ax.set_facecolor('silver')
plt.show()

# %% [markdown]
# ## SCATTER PLOT(RUNS VS STRIKE RATE)

# %%
plt.figure(figsize=(6,4))
plt.scatter(a['Runs'], a['Strike_rate'], alpha=0.5, color='purple')
plt.title("Scatter Plot of Runs vs Strike Rate")
plt.xlabel("Runs")
plt.ylabel("Strike Rate")
plt.grid(True)
plt.tight_layout()
plt.show()
